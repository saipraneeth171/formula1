# %%
print("hello")

# %%
dbutils.widgets.text("env", "dev") #run time parameters
env = dbutils.widgets.get("env")

# %%
print(env)

# %%
display(spark.sql(f"select * from formula1_{env}.bronze.sample"))
